# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # СТЕК ВЫЗОВА ФУНКЦИЙ

# %% [markdown]
# Вы сидите за столом и проходите этот курс. Допустим, в какой-то момент вы захотели сделать перерыв и пойти на кухню перекусить. Когда вы были на кухне, вам позвонил по телефону приятель, с которым вы начали беседовать. Вдруг в дверь позвонил курьер. Вы попросили друга повисеть на линии и отложили телефон, чтобы открыть дверь и принять доставку у курьера.
#
# Остановимся на моменте открытия входной двери и посчитаем, сколько у вас прерванных задач, а также поймём, в каком порядке вы будете их завершать. Итак, вам необходимо:
#
# Взять сумки у курьера.
#
# Завершить разговор с другом.
#
# Закончить перекус.
#
# Вернуться к прохождению курса.

# %% [markdown]
# ```
# Такая структура данных, в которой первым обрабатывается элемент (в данном случае задача), появившийся последним, называется стеком (или «стопкой»). Мы получили стек задач. Более формально он и называется стеком вызовов функции (call stack). В стеке действует правило LIFO (Last In, First Out) — «последний вошёл — первый вышел».
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Задание 5.4 (External resource)
#
# Напишите рекурсивную функцию multiply_lst(lst), которая перемножает элементы заданного списка lst между собой. Если в функцию передаётся пустой список, она должна возвращать 1.
#
# Примеры вызова функции:
# ```
# print(multiply_lst([1, 5, 2, 1.5]))
# ## 15
# print(multiply_lst([]))
# ## 1
#
# ```

# %%
def multiply_lst(lst):
    if not lst:  # Если список пустой, возвращаем 1
        return 1
    return lst[0] * multiply_lst(lst[1:])  # Рекурсивно умножаем элементы списка

print(multiply_lst([1, 5, 2, 1.5]))  # 15
print(multiply_lst([]))  # 1

# %% [markdown]
# # Задание 5.5 (External resource)
#
# Напишите рекурсивную функцию inv_sum_list(). На вход ей подаётся список из чисел, а она вычисляет сумму чисел, являющихся обратными к своим элементам. Обратным числу x называется число 1/x. Например, обратным числу 2 является 1/2 = 0.5.
#
# Например, если на вход программы подается список [10, 4, 8], то функция должна вернуть сумму 0.1 + 0.25 + 0.125 = 0.475.
#
# Если на вход функции передаётся пустой список, она должна возвращать 0.
#
# ```
# print(inv_sum_list([10, 4, 8]))
# ## 0.475
#
# print(inv_sum_list([10, 1, 2, 4, 8]))
# ## 1.975
#
# print(inv_sum_list([]))
# ## 0
#
# ```

# %%
# The function has several issues:
# 1. The `smll` function is not correctly implemented. It tries to append to `s` without initializing it.
# 2. The `smll` function is called without arguments.
# 3. The logic for summing the reciprocals is missing.

# Correct implementation:
def inv_sum_list(num):
   if not num:  # If the list is empty, return 0
      return 0
   return 1 / num[0] + inv_sum_list(num[1:])  # Recursively calculate the sum of reciprocals

print(inv_sum_list([10, 4, 8]))  # 0.475
print(inv_sum_list([10, 1, 2, 4, 8]))  # 1.975
print(inv_sum_list([]))  # 0
# Out:
# 0.475
# 1.975
# 0

# %% [markdown]
# ```
# Факториал — очень важная для математики и программирования функция. Она активно используется в комбинаторике, математическом
# анализе, в исследовании алгоритмов, в том числе алгоритмов машинного обучения, с которыми мы познакомимся далее в курсе.
# ```

# %%
def factorial(n):
    # Задаём условия выхода из рекурсии:
    if n==0: return 1
    if n==1: return 1
    # Во всех других случаях возвращаем
    # произведение текущего числа n и функции от n-1
    return factorial(n-1) * n

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Вызывается функция factorial(5). Стек вызова пополняется вызовом первой функции. Локальная переменная n = 5. Условие выхода из рекурсии не выполняется (n!= 1 и n!= 0), а значит, выполняется основной блок функции. В этом блоке мы пытаемся вычислить выражение n * factorial(n-1), что равносильно 5 * factorial(4). Так как результат работы функции factorial(4) заранее неизвестен, то для начала мы должны её выполнить.
#
# 2. Вызывается функция factorial(4). Стек вызова пополняется вызовом второй функции. Локальная переменная n = 4. Условие выхода всё ещё не выполняется, а значит, выполняется основной блок функции. Снова пытаемся вычислить выражение n * factorial(n-1), что равносильно 4 * factorial(3). Но, чтобы получить результат, сначала должна выполниться функция factorial(3).
#
# 3. Вызывается функция factorial(3). Теперь длина стека вызова равна 3. Всё повторяется вновь, только теперь n = 3. Вычисляем n  * factorial(n-1) = 3 * factorial(2). Переходим к вызову функции factorial(2).
#
# 4. Вызываем функцию factorial(2). Длина стека вызова увеличивается до 4. Для выполнения функции нам необходимо вычислить n * factorial(n-1)= 2 * factorial(1). Мы всё ещё не получили конкретного ответа, поэтому переходим к вызову функции factorial(1).
#
# 5. Вызываем функцию factorial(1). Длина стека вызова становится равной 5. В теле функции выполняется условие остановки, так как n==1. Это значит, что factorial(1) возвращает конкретное значение 1.
#
# 6. А теперь обратное движение: освобождаем стек вызова в направлении, противоположном его наполнению.  Последовательность завершения работы функций будет следующей:
#
#    1. На первом месте в стеке вызовов находится factorial(1) = 1. Функция отработала, поэтому стек вызовов она покидает, его длина становится равной четырём.
#    2. Затем выполняется функция factorial(2). Она должна вернуть 2 * factorial(1) = 2. После её выполнения стек вызова снова уменьшается, и количество ожидающих задач становится равным 3.
#    3. Следующая на очереди — функция factorial(3). Она возвращает значение выражения 3 * factorial(2) = 3 * 2 = 6. После её выполнения она покидает стек. Длина стека вызова составляет 2.
#    4. Затем переходим к выполнению функции factorial(4). Её возвращаемое значение — результат выражения 4 * factorial(3) = 4 * 6 = 24. Функция отработала и покинула стек. Его длина уменьшается до одного.
#    5. Наконец мы добрались до интересующей нас функции — factorial(5). Она должна вернуть результат выражения 5 * factorial(4) = 5 * 24 = 120. Процедура завершается, так как последняя функция покидает стек вызова и вызывать больше нечего. Выполняются следующие строки кода.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задание 5.6 (External resource)
#
# Напишем функцию combination(n, k), которая позволит нам автоматически вычислять значение сочетания по формуле, приведённой выше, для любых n и k.
#
# При расчёте воспользуйтесь рекурсивной функцией factorial(), которую мы написали выше. Можете сделать её внутренней для функции combination() или независимой функцией, на ваш вкус. Главное, добавьте в свой код объявление функции factorial().
#
# Пример работы функции:
#
# ```
# print(combination(n=10, k=5))
# ## 252.0
# print(combination(n=12, k=3))
# ## 220.0
# print(combination(n=1, k=1))
# ## 1.0
# print(combination(n=0, k=0))
# ## 1.0
# ```

# %%
def combination(n, k):
    # Рекурсивная функция факториала
    def factorial(x):
        if x == 0 or x == 1:    # базовый случай
            return 1
        return x * factorial(x - 1)  # рекурсия

    # Формула сочетаний
    return factorial(n) / (factorial(k) * factorial(n - k))

# Проверим:
print(combination(n=10, k=5))  # 252.0
print(combination(n=12, k=3))  # 220.0
print(combination(n=1, k=1))   # 1.0
print(combination(n=0, k=0))   # 1.0
# Out:
# 252.0
# 220.0
# 1.0
# 1.0

# %% [markdown]
# Задача
#
# ```
# Есть 𝑛 человек, нужно выбрать 𝑘 из них.
# Порядок не важен (то есть кто первый — не имеет значения).
# ```
#
# Формула сочетаний:
#
# ![image.png](attachment:image.png)
#
# **Читается как «число сочетаний из n по k».**
#
# 🔹 Как работает формула
#
# 𝑛! — это количество всех возможных перестановок n элементов.
#
# (𝑛-𝑘)! — мы делим на количество перестановок тех, кто не выбран.
#
# 𝑘! — делим на количество перестановок внутри выбранных (ведь порядок не важен).
#
# Таким образом формула убирает лишние перестановки и оставляет только уникальные комбинации.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Число единовременно ожидающих выполнения вызовов рекурсивной функции в стеке и называется глубиной рекурсии. Проще говоря, глубина рекурсии — это длина стека вызова.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задание 5.9 (External resource)
#
# Числа Фибоначчи — пример последовательности, которую можно получить рекурсивно. Каждое число из последовательности является суммой двух предыдущих.
#
# Можно записать рекурсивное выражение для расчёта n-ого числа из последовательности Фибоначчи:
#
# ![image.png](attachment:image.png)
#
# Напишите рекурсивную функцию fib(n), которая считает n-ое число Фибоначчи.
#
# Алгоритм работы функции:
#
# - Если n=1 или n=2, вернуть 1, так как первый и второй элементы ряда Фибоначчи равны единице.
# - Во всех остальных случаях вызвать эту же функцию с аргументами n-1 и n-2 и сложить результаты двух вызовов.

# %%
def fib(n):
   if n == 1 or n == 2:
      return 1
   return fib(n - 1) + fib(n - 2)

print(fib(1))
# 1
print(fib(2))
# 1
print(fib(6))
# 8
