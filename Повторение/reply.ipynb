# %%
def first_function():
    print("Hello world!")
first_function()
first_function()
# Out:
# Hello world!
# Hello world!

# %% [markdown]
# Вообще сигнатура — это многозначное слово. В переводе с латинского оно означает «обозначение». Соответственно, сигнатура функции — это непосредственно способ назвать функцию, отличить её от остальных.
# В Python для создания новой функции используется конструкция:
#
# def first_function():
#     print("Hello world!")
#
# Оператор, который позволяет функции передать какой-либо объект (число, строку, список, даже другую функцию) в то место кода, откуда вызывалась функция, называется return (от англ. "return" — «возвращать»). При этом говорят, что функция возвращает какой-либо результат.

# %% [markdown]
# Модифицируйте функцию root так, чтобы передавать степень корня было необязательно. Если степень корня не передана, функция должна возвращать значение квадратного корня.
#
# Проверьте своё решение, вызвав функцию root:
#
# print(root(81))
# # Должно быть напечатано:
# # 9.0

# %%
def root(value, n=2):
    # Как мы уже выяснили, чтобы посчитать
    # корень степени n из числа, можно возвести это число
    # в степень 1/n
    result = value ** (1/n)
    return result

# Посчитаем корень 3-ей степени (кубический корень) из 27
print(root(81))
# Будет напечатано:
# 3.0
# Out:
# 9.0

# %% [markdown]
# # Задание 7.9 (External resource)

# %% [markdown]
# Напишите функцию get_less(list_in, num), которая принимает на вход список list_in, состоящий из чисел, и ещё одно число num.
#
# Функция должна вернуть первое найденное число из списка, которое меньше переданного во втором аргументе. Если такого числа нет, необходимо вернуть None.
# ```
# print(get_less([1, 5, 8,  10], 8))
# # 1
#
# print(get_less([1, 5, 8,  10], 0))
# # None
# ```
# Вместо pass напишите тело функции
# ```
# def get_less(list_in, num):
#    pass
#
# ```

# %%
# The function get_less does not return a value, it only prints.
# When you call print(get_less(...)), it prints the result of the function call, which is None.
# To fix this, modify the function to return the value instead of printing it.

def get_less(list_in, num):
   for item in list_in:
      if item < num:
         return item
   return None

# Test the function
#print(get_less([1, 5, 8, 10], 8))  # 1
print(get_less([1, 5, 8, 10], 0))  # None
# Out:
# None

# %% [markdown]
# Функция обязательно должна ретернить если не указан reeturn функция будет выводить значени print() + None

# %% [markdown]
# # Задание 7.10 (External resource)

# %% [markdown]
# Напишите функцию split_date(date), которая принимает на вход строку, задающую дату, в формате ддммгггг без разделителей. Функция должна вернуть кортеж из чисел (int): день, месяц, год.
#
# Примечание. Здесь вам пригодятся срезы строк.
# ```
# print(split_date("31012019"))
# # (31, 1, 2019)
# ```

# %%
def split_date(date):
      # Extract day, month, and year using string slicing
   day = int(date[:2])   # First two characters represent the day
   month = int(date[2:4])  # Next two characters represent the month
   year = int(date[4:])  # Remaining characters represent the year
   return day, month, year



print(split_date("31012019"))
# (31, 1, 2019)
# Out:
# (31, 1, 2019)

# %% [markdown]
# подсказка как обычно была в задаче, был кортеж. Можно было просто сделать срез... Я не догодался.

# %% [markdown]
# # Задание 7.11 (External resource)

# %% [markdown]
# Напишите функцию is_prime(num), которая проверяет, является ли число простым.
#
# Функция должна вернуть True, если число простое, иначе — False.
#
# Примечание. Простым называют число, которое делится только на 1 или на само себя. Число 1 простым не является.

# %%
# Ваш текущий код содержит логические ошибки. Вот исправленный код:
def is_prime(i):
   # Проверяем, если число меньше или равно 1, оно не является простым
   if i <= 1:
      return False
   # Проверяем делимость числа на все числа от 2 до квадратного корня из i
   for n in range(2, int(i**0.5) + 1):
      if i % n == 0:  # Если число делится на n без остатка, оно не простое
         return False
   # Если делителей не найдено, число простое
   return True

# Тестируем функцию с переменными a и b
print(is_prime(a))  # False, так как 1 не является простым числом
print(is_prime(b))  # False, так как 10 делится на 2 и 5
# Out:
# False
# False
# False

# %% [markdown]
# # Задание 7.12 (External resource)

# %% [markdown]
# Напишите функцию between_min_max(...), которая принимает на вход числа через запятую.
#
# Функция возвращает среднее арифметическое между максимальным и минимальным значением этих чисел, то есть (max + min)/2.
#
# ```
# print(between_min_max(10))
# print(between_min_max(1,2,3,4,5))
# # 10.0
# # 3.0
# ```

# %%
def between_min_max(*num):
   # Find the maximum and minimum values from the input numbers
   max_val = max(num)
   min_val = min(num)
   # Calculate the average of the maximum and minimum values
   return (max_val + min_val) / 2

print(between_min_max(1,2,3,4,5))
# Out:
# 3.0

# %% [markdown]
# вот и сказались мои навыки не знения Python

# %% [markdown]
# # Задание 7.13 (External resource)

# %% [markdown]
# Skillfactory | Задача по Python
#
# Инструкция по использованию платформы
#
#
# Напишите функцию best_student(...), которая принимает на вход в виде именованных аргументов имена студентов и их номера в рейтинге (нагляднее в примере).
#
# Необходимо вернуть имя студента с минимальным номером по рейтингу.

# %%
def best_student(**students):
   # Find the student with the minimum ranking
   return min(students, key=students.get)
   # Метод .get(key) используется для получения значения, связанного с указанным ключом key в словаре.
   # В данном случае students.get возвращает значение (рейтинг) для каждого студента (ключа) в словаре students.
print(best_student(Tom=12, Mike=3))  # Mike
print(best_student(Tom=12))  # Tom
print(best_student(Tom=12, Jerry=1, Jane=2))  # Jerry
# Out:
# Mike
# Tom
# Jerry

# %% [markdown]
# # Задание 7.14 (External resource)

# %% [markdown]
# Напишите lambda-функцию is_palindrom(str), которая принимает на вход одну строку str (имя параметра - x) и проверяет, является ли она палиндромом, то есть читается ли она слева-направо и справа-налево одинаково.
#
# Функция возвращает yes, если строка является палиндромом, иначе — no.
#
# Примечание. Не пытайтесь схитрить — в тест включена проверка на то, что функция действительно является lambda.
#
# Пример:
# ```
# print(is_palindrom('1234'))
# print(is_palindrom('12321'))
# # no
# # yes
# ```

# %%
is_palindrom = lambda x: 'yes' if x == x[::-1] else 'no'

print(is_palindrom('1234'))
print(is_palindrom('12321'))
# no
# yes
# Lambda-функция — это анонимная функция, которая создаётся с помощью ключевого слова `lambda`.
# Она имеет следующий синтаксис:
# lambda аргументы: выражение
# Lambda-функции обычно используются для создания коротких функций, которые выполняют одно действие.

# В данном случае мы создаём lambda-функцию для проверки, является ли строка палиндромом.

# %% [markdown]
# # Задание 7.16 (External resource)

# %% [markdown]
# Перепишите функцию between_min_max из задания 7.12 в lambda-функцию. Функция принимает на вход числа через запятую и возвращает одно число — среднее между максимумом и минимумом этих чисел.
# ```
# Пример:
#
# print(between_min_max(1,2,3,4,5))
# # 3.0
# ```

# %%
def between_min_max(*num):
   # Find the maximum and minimum values from the input numbers
   max_val = max(num)
   min_val = min(num)
   # Calculate the average of the maximum and minimum values
   return (max_val + min_val) / 2

print(between_min_max(1,2,3,4,5))

# %%
between_min_max = lambda *num: (max(num) + min(num)) / 2

print(between_min_max(1,2,3,4,5))
# Out:
# 3.0

# %% [markdown]
# # Задание 7.17 (External resource)

# %% [markdown]
# Напишите функцию sort_ignore_case(ls), которая принимает на вход список ls и сортирует его без учёта регистра по алфавиту.
#
# Функция возвращает отсортированный список.
# ```
# Пример:
#
#
# print(sort_ignore_case(['Acc', 'abc']))
# # ['abc', 'Acc']
# ```

# %%
def sort_ignore_case(ls):
   return sorted(ls, key=str.lower)

print(sort_ignore_case(['Acc', 'abc']))
# Out:
# ['abc', 'Acc']

# %% [markdown]
# sorted - сортирует массив (ls - массив, key=str.lower = нижний регистр)

# %% [markdown]
# # Задание 7.18 (External resource)

# %% [markdown]
# Напишите функцию exchange(usd, rub, rate), которая может принимать на вход сумму в долларах (usd), сумму в рублях (rub) и обменный курс (rate). Обменный курс показывает, сколько стоит один доллар. Например, курс 85.46 означает, что один доллар стоит 85 рублей и 46 копеек.
#
# В функцию должно одновременно передавать два аргумента. Если передано менее двух аргументов, должна возникнуть ошибка ValueError('Not enough arguments'). Если же передано три аргумента, должна возникнуть ошибка: ValueError('Too many arguments').
#
# Функция должна находить третий аргумент по двум переданным. Например, если переданы суммы в разных валютах, должен возвращаться обменный курс. Если известны сумма в рублях и курс, должна быть получена эквивалентная сумма в долларах, аналогично — если передана сумма в долларах и обменный курс.
#
# Пример:
# ```
# print(exchange(usd=100, rub=8500))
# # 85.0
#
# print(exchange(usd=100, rate=85))
# # 8500
#
# print(exchange(rub=1000, rate=85))
# # 11.764705882352942
#
# print(exchange(rub=1000, rate=85, usd=90))
# # ValueError: Too many arguments
#
# print(exchange(rub=1000))
# # ValueError: Not enough arguments
# ```

# %%
def exchange(usd=None, rub=None, rate=None):
   # Проверяем количество переданных аргументов
   args = [usd, rub, rate]
   if args.count(None) > 1:
      raise ValueError('Not enough arguments')  # Если передано менее двух аргументов
   if args.count(None) == 0:
      raise ValueError('Too many arguments')  # Если передано три аргумента

   # Вычисляем недостающий аргумент
   if usd is None:
      return rub / rate  # Если неизвестна сумма в долларах
   elif rub is None:
      return usd * rate  # Если неизвестна сумма в рублях
   elif rate is None:
      return rub / usd  # Если неизвестен обменный курс

# Примеры использования
print(exchange(usd=100, rub=8500))  # 85.0
print(exchange(usd=100, rate=85))  # 8500
print(exchange(rub=1000, rate=85))  # 11.764705882352942
